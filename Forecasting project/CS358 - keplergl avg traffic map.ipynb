# %%
from keplergl import KeplerGl
import geopandas as gpd

# %%
pd.options.display.max_rows = None
province = gpd.read_file(r'E:\WFH\Thailand_province.geojson')
traffic = gpd.read_file(r'E:\WFH\traffic_province.geojson')
traffic
# Out:
#     OBJECTID PROV_CODE        PROV_NAMT                 PROV_NAME  YEAR  \
# 0          1        10    กรุงเทพมหานคร                   BANGKOK  2018
# 1          2        11      สมุทรปราการ              SAMUT PRAKAN  2018
# 2          3        12          นนทบุรี                NONTHABURI  2018
# 3          4        13         ปทุมธานี              PATHUM THANI  2018
# 4          5        14  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA  2018
# 5          7        16           ลพบุรี                  LOP BURI  2018
# 6          9        18           ชัยนาท                  CHAI NAT  2018
# 7         10        19          สระบุรี                  SARABURI  2018
# 8         11        20           ชลบุรี                 CHON BURI  2018
# 9         12        21            ระยอง                    RAYONG  2018
# 10        13        22         จันทบุรี               CHANTHABURI  2018
# 11        14        23             ตราด                      TRAT  2018
# ...

# %%
config = {'version': 'v1',
 'config': {'visState': {'filters': [],
   'layers': [{'id': '3yc1q36',
     'type': 'geojson',
     'config': {'dataId': 'traffic',
      'label': 'traffic',
      'color': [218, 112, 191],
      'columns': {'geojson': 'geometry'},
      'isVisible': True,
      'visConfig': {'opacity': 0.8,
       'thickness': 0.5,
       'strokeColor': [145, 0, 0],
       'colorRange': {'name': 'ColorBrewer Reds-5',
        'type': 'singlehue',
        'category': 'ColorBrewer',
        'colors': ['#fee5d9', '#fcae91', '#fb6a4a', '#de2d26', '#a50f15']},
       'strokeColorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'radius': 10,
       'sizeRange': [0, 10],
       'radiusRange': [0, 50],
       'heightRange': [0, 500],
       'elevationScale': 5,
       'stroked': True,
       'filled': True,
       'enable3d': False,
       'wireframe': False},
      'textLabel': [{'field': None,
        'color': [255, 255, 255],
        'size': 18,
        'offset': [0, 0],
        'anchor': 'start',
        'alignment': 'center'}]},
     'visualChannels': {'colorField': {'name': 'Traffic_avg', 'type': 'real'},
      'colorScale': 'quantile',
      'sizeField': None,
      'sizeScale': 'linear',
      'strokeColorField': None,
      'strokeColorScale': 'quantile',
      'heightField': None,
      'heightScale': 'linear',
      'radiusField': None,
      'radiusScale': 'linear'}},
    {'id': 'stklvha',
     'type': 'geojson',
     'config': {'dataId': 'province',
      'label': 'province',
      'color': [147, 147, 147],
      'columns': {'geojson': 'geometry'},
      'isVisible': True,
      'visConfig': {'opacity': 0.8,
       'thickness': 0.5,
       'strokeColor': [77, 77, 77],
       'colorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'strokeColorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'radius': 10,
       'sizeRange': [0, 10],
       'radiusRange': [0, 50],
       'heightRange': [0, 500],
       'elevationScale': 5,
       'stroked': True,
       'filled': True,
       'enable3d': False,
       'wireframe': False},
      'textLabel': [{'field': None,
        'color': [255, 255, 255],
        'size': 18,
        'offset': [0, 0],
        'anchor': 'start',
        'alignment': 'center'}]},
     'visualChannels': {'colorField': None,
      'colorScale': 'quantile',
      'sizeField': None,
      'sizeScale': 'linear',
      'strokeColorField': None,
      'strokeColorScale': 'quantile',
      'heightField': None,
      'heightScale': 'linear',
      'radiusField': None,
      'radiusScale': 'linear'}}],
   'interactionConfig': {'tooltip': {'fieldsToShow': {'province': ['OBJECTID',
       'PROV_CODE',
       'PROV_NAMT',
       'PROV_NAME',
       'YEAR'],
      'traffic': ['OBJECTID', 'PROV_CODE', 'PROV_NAMT', 'PROV_NAME', 'YEAR']},
     'enabled': True},
    'brush': {'size': 0.5, 'enabled': False}},
   'layerBlending': 'normal',
   'splitMaps': [],
   'animationConfig': {'currentTime': None, 'speed': 1}},
  'mapState': {'bearing': 0,
   'dragRotate': False,
   'latitude': 12.060359479223978,
   'longitude': 103.11510943461961,
   'pitch': 0,
   'zoom': 4.451941083083048,
   'isSplit': False},
  'mapStyle': {'styleType': 'dark',
   'topLayerGroups': {},
   'visibleLayerGroups': {'label': True,
    'road': True,
    'border': False,
    'building': True,
    'water': True,
    'land': True,
    '3d building': False},
   'threeDBuildingColor': [9.665468314072013,
    17.18305478057247,
    31.1442867897876],
   'mapStyles': {}}}}

# %%
traffic_map = KeplerGl(height=800, data={'province':province, 'traffic':traffic}, config=config)
traffic_map
# Out:
# User Guide: https://github.com/keplergl/kepler.gl/blob/master/docs/keplergl-jupyter/user-guide.md
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': '3yc1q36', 'type': …
